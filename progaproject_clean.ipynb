# %%
import os
import time
import functools
from bs4 import BeautifulSoup 
from urllib import request
from selenium import webdriver
from selenium.common.exceptions import ElementNotInteractableException

# %%
class BeerDataExport:
    
    def __init__(self, ffdir, geckodriver_dir, url, source_type='bar'):
        
        # source_type options: 'bar', 'brewery', 'acc' (personal account export), 'wishlist'
        
        self.ffdir = ffdir
        self.geckodriver_dir = geckodriver_dir
        self.url = url
        self.source_type = source_type
        self.run_the_browser(ffdir, geckodriver_dir, url, source_type)
    
    def run_the_browser(self, ffdir, geckodriver_dir, url, source_type):
        
        ffprofile = webdriver.FirefoxProfile(ffdir)
        driver = webdriver.Firefox(executable_path = geckodriver_dir, firefox_profile=ffprofile) 
        driver.get(url)
        
        if self.source_type == 'bar':
            filename = 'bar'
            btn = driver.find_element_by_css_selector("a.yellow.button.more.show-more-section.track-click")
        elif self.source_type == 'brewery':
            filename = 'brewery'
            btn = driver.find_element_by_css_selector("a.button.yellow")
        elif self.source_type == 'acc':
            filename = 'acc'
            btn = driver.find_element_by_css_selector("a.button.yellow.more.more-list-items.track-click")
        elif self.source_type == 'wishlist':
            filename = 'wishlist'
            btn = driver.find_element_by_css_selector("a.yellow.button.more.more-list-items")
        else:
            print('no such source type.')
        
        old_position = 0
        new_position = None

        while True:
            try:
                while new_position != old_position:
                    old_position = driver.execute_script(
                            ("return (window.pageYOffset !== undefined) ?"
                             " window.pageYOffset : (document.documentElement ||"
                             " document.body.parentNode || document.body);"))
                    time.sleep(1)
                    driver.execute_script((
                            "var scrollingElement = (document.scrollingElement ||"
                            " document.body);scrollingElement.scrollTop ="
                            " scrollingElement.scrollHeight;"))
                    btn.click()
                    new_position = driver.execute_script(
                            ("return (window.pageYOffset !== undefined) ?"
                             " window.pageYOffset : (document.documentElement ||"
                             " document.body.parentNode || document.body);"))
            except ElementNotInteractableException:
                with open('{}.html'.format(filename), 'w') as f:
                    f.write(driver.page_source)
                break

# %% [markdown]
# Тесты

# %%
BeerDataExport('/Users/macbookpro/Library/Application Support/Firefox/Profiles/p4mnjkfe.untappd',
               '/Users/macbookpro/Downloads/geckodriver',
               'https://untappd.com/v/share-house/7728362?ng_menu_id=2af7b1fd-7ca0-4ed7-9ecf-4db4920877c9',
               source_type='bar')

# %%
BeerDataExport('/Users/macbookpro/Library/Application Support/Firefox/Profiles/p4mnjkfe.untappd',
               '/Users/macbookpro/Downloads/geckodriver',
               'https://untappd.com/AntiFactory/beer',
               source_type='brewery')

# %%
BeerDataExport('/Users/macbookpro/Library/Application Support/Firefox/Profiles/p4mnjkfe.untappd',
               '/Users/macbookpro/Downloads/geckodriver',
               'https://untappd.com/user/sheamrock/beers',
               source_type='acc')

# %%
BeerDataExport('/Users/macbookpro/Library/Application Support/Firefox/Profiles/p4mnjkfe.untappd',
               '/Users/macbookpro/Downloads/geckodriver',
               'https://untappd.com/user/mettathrone/wishlist',
               source_type='wishlist')

# %%
class BeerDataParse:
    
    def __init__(self):
        pass
    
    def BeautifyOutput(func):
        @functools.wraps(func)
        def wrapper(*args, **kwargs):
            bar_beauty = func(*args, **kwargs)
            print('haha')
            for beer in bar_beauty:
                print(beer['beer'] + '\n' + beer['style'] + '\n' + str(beer['rating']) + '\n' 
                      + beer['brewery'] + '\n' + beer['link'] + '\n\n')
        return wrapper
            
    @BeautifyOutput    
    def parse_the_list(self, filename, source_type):
        
        beers = []
        
        with open(filename) as f:
            contents = f.read()
        soup = BeautifulSoup(contents)
        
        if source_type == 'bar':
            
            beers_raw = soup.find_all("div", class_="beer-details")
            for beer in beers_raw:
                h5 = beer.find('h5')
                h5_a = h5.find('a')    
                beer_link = f"https://untappd.com{h5_a['href']}"
                beer_name = h5_a.get_text()
                brewery = beer.find("a", attrs={"data-href": ":brewery"}).get_text()
                style = h5.find("em").get_text()
                try:
                    rating = float(beer.find("div", class_="caps")["data-rating"])
                except:
                    rating = None
                beers.append({"beer": beer_name, "style": style, "rating": rating, "brewery": brewery, "link": beer_link})
    
        elif source_type == 'brewery':
            
            ratings_raw = soup.find_all('span', class_='num')
            ratings = []
            for rt in ratings_raw:
                rating_raw = rt.get_text()
                rating_line = str(rating_raw)
                rating = rating_line[1:-1]
                ratings.append(rating)
            beers_raw = soup.find_all('div', class_='beer-details')
            i = 0
            for beer in beers_raw:
                a = beer.find('a')
                beer_name = beer.find('p').get_text()
                beer_link = f"https://untappd.com{a['href']}"
                brewery = 'similar'
                style = beer.find('p', class_='style').get_text()
                try:
                    rating = ratings[i]
                except:
                    rating = None
                i += 1
                beers.append({"beer": beer_name, "style": style, "rating": rating, "brewery": brewery, "link": beer_link}) 
                
        elif source_type == 'acc':
            
            beers_raw = soup.find_all("div", class_="beer-details")
            for beer in beers_raw:
                p = beer.find('p')
                a = p.find('a')
                beer_name = p.get_text()
                beer_link = f"https://untappd.com{a['href']}"
                brewery = beer.find('p', class_='brewery').get_text()
                style = beer.find('p', class_='style').get_text()
                try:
                    rating = float(beer.find("div", class_="caps")["data-rating"])
                except:
                    rating = None
                beers.append({"beer": beer_name, "style": style, "rating": rating, "brewery": brewery, "link": beer_link}) 

        elif source_type == 'wishlist':
            
            beers_raw = soup.find_all('div', class_='item-info')
            for beer in beers_raw:
                beer_name = beer.find('h2').get_text()
                h2 = beer.find('h2')
                a = h2.find('a')
                beer_link = f"https://untappd.com{a['href']}"
                brewery = beer.find('h3').get_text()
                desc = beer.find('h4').get_text()
                style = desc.split('•')[0]
                try:
                    rating = float(beer.find("div", class_="caps")["data-rating"])
                except:
                    rating = None
                beers.append({"beer": beer_name, "style": style, "rating": rating, "brewery": brewery, "link": beer_link}) 

        else:
            print('no such source type.')
        
        with open('beers.txt', 'w') as f:
            f.write(str(beers))
        
        return beers

# %% [markdown]
# Тесты

# %%
bdp = BeerDataParse()

# %%
bdp.parse_the_list('bar.html', 'bar')
# Out:
# haha
# Gueuze 100% Lambic Bio
# Lambic - Gueuze
# 4.208
# Brasserie Cantillon
# https://untappd.com/b/brasserie-cantillon-gueuze-100-lambic-bio/56829
#
#
# Rosé de Gambrinus (2019)
# Lambic - Framboise
# 4.319
# Brasserie Cantillon
# https://untappd.com/b/brasserie-cantillon-rose-de-gambrinus-2019/3079645
#
#
# Black Radiation OAK Chivas Edition
# Stout - Russian Imperial
# 4.095
# RMBrew
# https://untappd.com/b/rmbrew-black-radiation-oak-chivas-edition/2784315
#
#
# Mjød Липа
# Mead - Metheglin
# 4.001
# Gurin Craft
# https://untappd.com/b/gurin-craft-mjod-lipa/3637173
#
#
# Oppa! Apa
# Pale Ale - American
# 3.768
# RMBrew
# https://untappd.com/b/rmbrew-oppa-apa/3527233
#
#
# Окрошка
# Sour - Gose
# 3.579
# Шляпа Brewery
# https://untappd.com/b/shlyapa-brewery-okroshka/3470265
#
#
# PARTY DIPA
# IPA - Imperial / Double
# 3.687
# RMBrew
# https://untappd.com/b/rmbrew-party-dipa/2063419
#
#
# MouseTrap
# Sour - Fruited
# 3.506
# RMBrew
# https://untappd.com/b/rmbrew-mousetrap/3749983
#
#
# Too Many Options
# Stout - Milk / Sweet
# 3.817
# RMBrew
# https://untappd.com/b/rmbrew-too-many-options/3552908
#
#
# Wikkie
# Sour - Other
# 3.878
# Ostrovica
# https://untappd.com/b/ostrovica-wikkie/3702538
#
#
# FANATIC
# Pale Ale - American
# 4.245
# Ostrovica
# https://untappd.com/b/ostrovica-fanatic/3819113
#
#
# Есенин. Том 2 / Esenin. Volume 2
# Stout - Russian Imperial
# None
# Brewlok Brewery
# https://untappd.com/b/brewlok-brewery-esenin-tom-2-esenin-volume-2/3828610
#
#
# Milky Boy
# Stout - Milk / Sweet
# 3.79
# Sabotage
# https://untappd.com/b/sabotage-milky-boy/3761222
#
#
# Sweet Disaster
# Stout - Pastry
# 3.916
# Sabotage
# https://untappd.com/b/sabotage-sweet-disaster/3080321
#
#
# Electrocat
# IPA - American
# 3.926
# Sabotage
# https://untappd.com/b/sabotage-electrocat/3202918
#
#
# Pure Shores
# Stout - Milk / Sweet
# 3.726
# Red Button Brewery
# https://untappd.com/b/red-button-brewery-pure-shores/2502623
#
#
# BUMPY
# IPA - American
# 3.896
# Red Button Brewery
# https://untappd.com/b/red-button-brewery-bumpy/3629982
#
#
# Most Wonderful Time 4 A Beer
# Stout - Milk / Sweet
# 3.957
# Red Button Brewery
# https://untappd.com/b/red-button-brewery-most-wonderful-time-4-a-beer/2427008
#
#
# Schoolyard
# IPA - Triple
# 4.091
# Time Bomb Brewery
# https://untappd.com/b/time-bomb-brewery-schoolyard/3668058
#
#
# LEÖN
# Belgian Strong Dark Ale
# 3.669
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-leon/336499
#
#
# LUNE - ANNATA 2012
# Barleywine - English
# 4.291
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-lune-annata-2012/668080
#
#
# XYAUYÙ etichetta oro/golden label - RISERVA 2014
# Barleywine - Other
# 4.41
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-etichetta-oro-golden-label-riserva-2014/573390
#
#
# XYAUYU' KENTUCKY - RISERVA 2015
# Barleywine - Other
# 4.542
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-kentucky-riserva-2015/2915525
#
#
# XYAUYÙ BARREL - RISERVA 2014
# Barleywine - Other
# 4.494
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-barrel-riserva-2014/2963304
#
#
# Karlovar Nulevočká
# Non-Alcoholic Beer
# 2.933
# Pivovar Černá Hora
# https://untappd.com/b/pivovar-cerna-hora-karlovar-nulevocka/626450
#
#
# Чертово Яблоко
# Cider - Herbed / Spiced / Hopped
# 4.09
# Applehead
# https://untappd.com/b/applehead-chertovo-yabloko/3811786
#
#
# Pumpkin Apple (2019)
# Cider - Other Fruit
# 3.943
# Applehead
# https://untappd.com/b/applehead-pumpkin-apple-2019/3811784
#
#
# Noble Apple (2019)
# Cider - Dry
# 4.292
# Applehead
# https://untappd.com/b/applehead-noble-apple-2019/3811787
#
#
# 3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 17|18) Blend No. 25
# Lambic - Gueuze
# 4.44
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-17-18-blend-no-25/3028849
#
#
# 3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 18|19) Blend No. 49
# Lambic - Gueuze
# 4.258
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-18-19-blend-no-49/3596260
#
#
# 3 Fonteinen Oude Geuze (season 17|18) Blend No. 45
# Lambic - Gueuze
# 4.418
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-17-18-blend-no-45/2984628
#
#
# IPA
# IPA - American
# 3.533
# Brouwerij Kees
# https://untappd.com/b/brouwerij-kees-ipa/3622526
#
#
# Barley Wine
# Barleywine - American
# 3.761
# Brouwerij Kees
# https://untappd.com/b/brouwerij-kees-barley-wine/1103930
#
#
# American Brown Ale
# Brown Ale - American
# 3.33
# Brouwerij Kees
# https://untappd.com/b/brouwerij-kees-american-brown-ale/3525730
#
#
# Sigma Wild Forest
# Sour - Flanders Oud Bruin
# 3.968
# Brouwerij Alvinne
# https://untappd.com/b/brouwerij-alvinne-sigma-wild-forest/3617200
#
#
# Sequence Series #008 - Red Ale Reserve
# Red Ale - Imperial / Double
# 4.116
# Uiltje Brewing Company
# https://untappd.com/b/het-uiltje-sequence-series-008-red-ale-reserve/3598266
#
#
# Sequence Series #007 - 2019 Speyside Blend
# Stout - Imperial / Double
# 4.153
# Uiltje Brewing Company
# https://untappd.com/b/het-uiltje-sequence-series-007-2019-speyside-blend/3588016
#
#
# Cuvée De Mortagne Vermouth (2019)
# Belgian Quadrupel
# 4.02
# Brouwerij Alvinne
# https://untappd.com/b/brouwerij-alvinne-cuvee-de-mortagne-vermouth-2019/3497217
#
#
# Cuvée De Mortagne Marsala (2019)
# Belgian Quadrupel
# 3.903
# Brouwerij Alvinne
# https://untappd.com/b/brouwerij-alvinne-cuvee-de-mortagne-marsala-2019/3540902
#
#
# Vivizero
# Cider - Dry
# 3.566
# Bullevie
# https://untappd.com/b/bullevie-vivizero/2626346
#
#
# Brexit
# Cider - Traditional
# 3.546
# Bullevie
# https://untappd.com/b/bullevie-brexit/2626348
#
#
# Risk
# Stout - Imperial / Double
# 4.02
# Selfmade Brewery
# https://untappd.com/b/selfmade-brewery-risk/2414360
#
#
# Dessert Eagle Milk & Honey Ed.
# Stout - Milk / Sweet
# 3.728
# Selfmade Brewery
# https://untappd.com/b/selfmade-brewery-dessert-eagle-milk-and-honey-ed/3773452
#
#
# Pale Ale
# Pale Ale - American
# 3.989
# Ostrovica
# https://untappd.com/b/ostrovica-pale-ale/3799694
#
#
# Altmüller Hefe-Weissbier
# Hefeweizen
# 3.589
# Brauerei Bischofshof
# https://untappd.com/b/brauerei-bischofshof-altmuller-hefe-weissbier/161294
#
#
# Altmüller Hell
# Lager - Helles
# 3.408
# Brauerei Bischofshof
# https://untappd.com/b/brauerei-bischofshof-altmuller-hell/161203
#
#
# Altvater Weissbierbock
# Bock - Weizenbock
# 3.617
# Brauerei Bischofshof
# https://untappd.com/b/brauerei-bischofshof-altvater-weissbierbock/1530197
#
#
# Blood Orange Gose
# Sour - Fruited Gose
# 3.714
# Anderson Valley Brewing Company
# https://untappd.com/b/anderson-valley-brewing-company-blood-orange-gose/791939
#
#
# Briney Melon Gose
# Sour - Fruited Gose
# 3.77
# Anderson Valley Brewing Company
# https://untappd.com/b/anderson-valley-brewing-company-briney-melon-gose/1048349
#
#
# Huge Arker Bourbon Barrel Imperial Stout
# Stout - Russian Imperial
# 4.091
# Anderson Valley Brewing Company
# https://untappd.com/b/anderson-valley-brewing-company-huge-arker-bourbon-barrel-imperial-stout/171612
#
#
# Коза в Малиннике
# Fruit Beer
# 3.508
# New Riga's Brewery
# https://untappd.com/b/new-riga-s-brewery-koza-v-malinnike/3813302
#
#
# Christmas Ale (2019)
# Winter Ale
# 3.962
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-christmas-ale-2019/3508001
#
#
# Abt 12 (2019)
# Belgian Quadrupel
# 3.991
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-abt-12-2019/3026897
#
#
# Tripel (2019)
# Belgian Tripel
# 3.849
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-tripel-2019/3026898
#
#
# Watou Tripel
# Belgian Tripel
# 3.671
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-watou-tripel/371
#
#
# Brauherren Alkoholfrei
# Non-Alcoholic Beer
# 2.28
# Einbecker Brauhaus
# https://untappd.com/b/einbecker-brauhaus-brauherren-alkoholfrei/81324
#
#
# Amarillo Soup
# IPA - Session / India Session Ale
# 3.598
# Cervezas Domus
# https://untappd.com/b/cervezas-domus-amarillo-soup/3430567
#
#
# Simcoe Soup
# IPA - Session / India Session Ale
# 3.662
# Cervezas Domus
# https://untappd.com/b/cervezas-domus-simcoe-soup/3467560
#
#
# Citra Soup
# IPA - Session / India Session Ale
# 3.625
# Cervezas Domus
# https://untappd.com/b/cervezas-domus-citra-soup/2753428
#
#
# Iberus
# IPA - Imperial / Double
# 3.577
# Cervezas Domus
# https://untappd.com/b/cervezas-domus-iberus/1626108
#
#
# Santo Tomé
# Belgian Dubbel
# 3.561
# Cervezas Domus
# https://untappd.com/b/gatopardo-craft-beer-santo-tome/3235160
#
#
# London Pale Ale
# Pale Ale - English
# 3.286
# Sambrook's Brewery
# https://untappd.com/b/sambrook-s-brewery-london-pale-ale/770933
#
#
# Sixex
# Strong Ale - English
# 3.545
# Joseph Holt
# https://untappd.com/b/joseph-holt-sixex/55430
#
#
# 1849 Champion Ale
# English Bitter
# 3.374
# Joseph Holt
# https://untappd.com/b/joseph-holt-1849-champion-ale/33347
#
#
# Einbecker Ainpöckisch Bier 1378
# Bock - Hell / Maibock / Lentebock
# 3.523
# Einbecker Brauhaus
# https://untappd.com/b/einbecker-brauhaus-einbecker-ainpockisch-bier-1378/1478517
#
#
# Einbecker Ur-Bock Dunkel
# Bock - Single / Traditional
# 3.298
# Einbecker Brauhaus
# https://untappd.com/b/einbecker-brauhaus-einbecker-ur-bock-dunkel/15128
#
#
# Einbecker Ur-Bock Hell
# Bock - Hell / Maibock / Lentebock
# 3.093
# Einbecker Brauhaus
# https://untappd.com/b/einbecker-brauhaus-einbecker-ur-bock-hell/1937
#
#
# Black Cat In the Dark Room
# Porter - Imperial / Double Baltic
# 3.858
# DARKSIDE
# https://untappd.com/b/darkside-black-cat-in-the-dark-room/3638677
#
#
# Вторая личность
# Porter - Other
# 3.97
# 4BREWERS
# https://untappd.com/b/4brewers-chetyre-pivovara-vtoraya-lichnost/2016091
#
#
# ABV Not IBU: Citra
# IPA - Imperial / Double
# 3.554
# AF Brew
# https://untappd.com/b/af-brew-abv-not-ibu-citra/3793348
#
#
# ABV Not IBU: Nelson Sauvin
# IPA - Imperial / Double
# 3.468
# AF Brew
# https://untappd.com/b/af-brew-abv-not-ibu-nelson-sauvin/3793347
#
#
# ALL • GRAIN • CORE
# Stout - Other
# 3.729
# AF Brew
# https://untappd.com/b/af-brew-all-grain-core/3557493
#
#
# Annual Farewell Freak Show
# Stout - Imperial / Double Pastry
# 3.882
# AF Brew
# https://untappd.com/b/af-brew-annual-farewell-freak-show/3637188
#
#
# Another Million Minutes On Peach
# American Wild Ale
# 3.817
# AF Brew
# https://untappd.com/b/af-brew-another-million-minutes-on-peach/3718066
#
#
# Dark Side of the Overhype
# Stout - Imperial / Double Pastry
# 4.133
# AF Brew
# https://untappd.com/b/af-brew-dark-side-of-the-overhype/3552894
#
#
# Mash. Boil. Beans. Repeat.
# Stout - Imperial / Double
# 3.725
# AF Brew
# https://untappd.com/b/af-brew-mash-boil-beans-repeat/3793442
#
#
# Popcorn Pimp
# Stout - Imperial / Double Pastry
# 4.121
# AF Brew
# https://untappd.com/b/af-brew-popcorn-pimp/2879438
#
#
# Trappistes Rochefort 10
# Belgian Quadrupel
# 4.107
# Abbaye Notre-Dame de Saint-Rémy
# https://untappd.com/b/abbaye-notre-dame-de-saint-remy-trappistes-rochefort-10/6766
#
#
# Wild Turkey Bourbon Barrel Stout
# Stout - Oatmeal
# 3.87
# Anderson Valley Brewing Company
# https://untappd.com/b/anderson-valley-brewing-company-wild-turkey-bourbon-barrel-stout/130880
#
#
# METODO CLASSICO - RISERVA 2016
# Bière de Champagne / Bière Brut
# 3.899
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-metodo-classico-riserva-2016/2306514
#
#
# SUZI DRY
# Fruit Beer
# 3.507
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-suzi-dry/1094621
#
#
# TERRE - ANNATA 2010
# Barleywine - Other
# 4.357
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-terre-annata-2010/1186811
#
#
# XYAUYU' FUME - RISERVA 2014
# Barleywine - Other
# 4.419
# BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery
# https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-fume-riserva-2014/2915524
#
#
# HYPNOTIZE
# Sour - Gose
# 3.516
# Bakunin Brewing Co.
# https://untappd.com/b/bakunin-brewing-co-hypnotize/3821955
#
#
# La Trappe Quadrupel Oak Aged Batch #34
# Belgian Quadrupel
# 4.335
# Bierbrouwerij De Koningshoeven
# https://untappd.com/b/bierbrouwerij-de-koningshoeven-la-trappe-quadrupel-oak-aged-batch-34/3169411
#
#
# Milk Brothers
# Stout - Milk / Sweet
# 3.909
# Big Village Brewery
# https://untappd.com/b/big-village-brewery-milk-brothers/1482080
#
#
# Quartet X
# Belgian Quadrupel
# 4.181
# Big Village Brewery
# https://untappd.com/b/big-village-brewery-quartet-x/2112749
#
#
# Альтер Эго
# Stout - Imperial / Double Milk
# 4.221
# Big Village Brewery
# https://untappd.com/b/big-village-brewery-alter-ego/3801547
#
#
# Bye Bye Take Your Pie
# Stout - Imperial / Double Milk
# 3.93
# Bottle Share
# https://untappd.com/b/bottle-share-bye-bye-take-your-pie/3635282
#
#
# Hopmaxa
# IPA - American
# 3.68
# Bottle Share
# https://untappd.com/b/bottle-share-hopmaxa/3686477
#
#
# Wrong Way - Milky Way
# Stout - Milk / Sweet
# 3.899
# Bottle Share
# https://untappd.com/b/bottle-share-wrong-way-milky-way/1573347
#
#
# Fantome D'Automne 2019
# Farmhouse Ale - Saison
# 3.643
# Brasserie Fantôme
# https://untappd.com/b/brasserie-fantome-fantome-d-automne-2019/3579400
#
#
# Imperial Donkey
# Stout - Imperial / Double
# 3.588
# Brasserie de la Senne
# https://untappd.com/b/brasserie-de-la-senne-imperial-donkey/3047149
#
#
# Schieven Enthusiasm
# Farmhouse Ale - Other
# 3.754
# Brasserie de la Senne
# https://untappd.com/b/brasserie-de-la-senne-schieven-enthusiasm/3516649
#
#
# Commerzienrat Riegele Privat
# Lager - Helles
# 3.368
# Brauhaus Riegele
# https://untappd.com/b/brauhaus-riegele-commerzienrat-riegele-privat/40567
#
#
# Burning Jam: Pink Guava & Melon
# Sour - Fruited Gose
# 3.647
# Brew Division
# https://untappd.com/b/brew-division-burning-jam-pink-guava-and-melon/3717957
#
#
# Weißglück
# Hefeweizen
# 3.627
# Brew Division
# https://untappd.com/b/brew-division-weissgluck/1823339
#
#
# Paradox Islay
# Stout - Imperial / Double
# 4.026
# BrewDog
# https://untappd.com/b/brewdog-paradox-islay/16652
#
#
# Favorite cookies (brownie + vanilla)
# Stout - Pastry
# 3.807
# BrewT!
# https://untappd.com/b/brewt-favorite-cookies-brownie-vanilla/3464066
#
#
# Броневик
# Stout - Russian Imperial
# 3.954
# Brewlok Brewery
# https://untappd.com/b/brewlok-brewery-bronevik/3706557
#
#
# Достоевский. Том 5
# Porter - Imperial / Double Baltic
# 4.225
# Brewlok Brewery
# https://untappd.com/b/brewlok-brewery-dostoevskij-tom-5/3805936
#
#
# 3 Fonteinen Oude Geuze (season 18|19) Blend No. 53
# Lambic - Gueuze
# 4.227
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-season-18-19-blend-no-53/3566479
#
#
# 3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 18|19) Blend No. 39
# Lambic - Gueuze
# 4.388
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-18-19-blend-no-39/3495230
#
#
# 3 Fonteinen Oude Geuze Cuvée Armand & Gaston (season 18|19) Blend No. 41
# Lambic - Gueuze
# 4.392
# Brouwerij 3 Fonteinen
# https://untappd.com/b/brouwerij-3-fonteinen-3-fonteinen-oude-geuze-cuvee-armand-and-gaston-season-18-19-blend-no-41/3495224
#
#
# Oude Geuze White Vermouth Foeders
# Lambic - Gueuze
# 3.996
# Brouwerij Boon
# https://untappd.com/b/brouwerij-boon-oude-geuze-white-vermouth-foeders/2642515
#
#
# Kriekenbier wheat
# Fruit Beer
# 3.515
# Brouwerij Cornelissen
# https://untappd.com/b/brouwerij-cornelissen-kriekenbier-wheat/197575
#
#
# Hel & Verdoemenis Bowmore barrel aged
# Stout - Russian Imperial
# 4.113
# Brouwerij De Molen
# https://untappd.com/b/brouwerij-de-molen-hel-and-verdoemenis-bowmore-barrel-aged/462744
#
#
# Said & Done Bowmore Barrel Aged
# Stout - Other
# 4.002
# Brouwerij De Molen
# https://untappd.com/b/brouwerij-de-molen-said-and-done-bowmore-barrel-aged/2792815
#
#
# XXX-Bitter
# IPA - Belgian
# 3.656
# Brouwerij De Ranke
# https://untappd.com/b/brouwerij-de-ranke-xxx-bitter/463346
#
#
# Barrel Project 19.12
# Farmhouse Ale - Saison
# 3.762
# Brouwerij Kees
# https://untappd.com/b/brouwerij-kees-barrel-project-19-12/3525729
#
#
# Tuverbol (2019)
# Belgian Strong Golden Ale
# 3.564
# Brouwerij Loterbol
# https://untappd.com/b/brouwerij-loterbol-tuverbol-2019/3570886
#
#
# Prior 8
# Belgian Dubbel
# 3.725
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-prior-8/475
#
#
# Tripel
# Belgian Tripel
# 3.782
# Brouwerij St.Bernardus
# https://untappd.com/b/brouwerij-st-bernardus-tripel/481
#
#
# Arise
# IPA - International
# 3.793
# COVEN Brewery
# https://untappd.com/b/coven-brewery-arise/3214410
#
#
# Hell  Awaits
# Sour - Fruited Gose
# 4.06
# COVEN Brewery
# https://untappd.com/b/coven-brewery-hell-awaits/3435903
#
#
# THE ONLY
# Stout - Russian Imperial
# 3.865
# COVEN Brewery
# https://untappd.com/b/coven-brewery-the-only/3683759
#
#
# Double Iriskiss
# Stout - Imperial / Double Pastry
# 3.758
# Courage Brewery
# https://untappd.com/b/courage-brewery-double-iriskiss/3628418
#
#
# Green Team
# IPA - Sour
# 3.779
# Courage Brewery
# https://untappd.com/b/courage-brewery-green-team/3628417
#
#
# Hoppy Bitch
# Pale Ale - American
# 3.65
# Courage Brewery
# https://untappd.com/b/courage-brewery-hoppy-bitch/3628419
#
#
# The Decider Semi-Dry
# Cider - Traditional
# 3.728
# Courage Brewery
# https://untappd.com/b/courage-brewery-the-decider-semi-dry/3689000
#
#
# Wisharing
# Fruit Beer
# 3.441
# Courage Brewery
# https://untappd.com/b/courage-brewery-wisharing/3628416
#
#
# Антидот
# IPA - American
# 3.645
# Courage Brewery
# https://untappd.com/b/courage-brewery-antidot/3808696
#
#
# Дом в Айдахо
# IPA - American
# 3.842
# Courage Brewery
# https://untappd.com/b/courage-brewery-dom-v-ajdaho/2648884
#
#
# Дом культуры 2.0
# IPA - American
# 3.644
# Courage Brewery
# https://untappd.com/b/courage-brewery-dom-kultury-2-0/3557939
#
#
# Дурдом
# IPA - Imperial / Double
# 3.799
# Courage Brewery
# https://untappd.com/b/courage-brewery-durdom/2473492
#
#
# Тропический Ёж
# Sour - Fruited
# 3.688
# Courage Brewery
# https://untappd.com/b/courage-brewery-tropicheskij-yozh/3783413
#
#
# Seven Sins (Belgian Tripel)
# Belgian Tripel
# 3.595
# Dargett Brewery
# https://untappd.com/b/dargett-brewery-seven-sins-belgian-tripel/1775517
#
#
# Motorolie
# Stout - Russian Imperial
# 3.894
# De Moersleutel
# https://untappd.com/b/de-moersleutel-motorolie/1733389
#
#
# I Love You With My Stout (batch #014)
# Stout - Imperial / Double
# 3.897
# Evil Twin Brewing
# https://untappd.com/b/evil-twin-brewing-i-love-you-with-my-stout-batch-014/3125751
#
#
# BANANA BANG
# Sour - Fruited
# 3.809
# FFF BREW
# https://untappd.com/b/fff-brew-banana-bang/3716473
#
#
# Old Man Hattan (2019)
# Strong Ale - American
# 4.152
# Firestone Walker Brewing Company
# https://untappd.com/b/firestone-walker-brewing-company-old-man-hattan-2019/3330670
#
#
# Canadian Breakfast Stout (CBS) (2019)
# Stout - Imperial / Double Coffee
# 4.391
# Founders Brewing Co.
# https://untappd.com/b/founders-brewing-co-canadian-breakfast-stout-cbs-2019/3478348
#
#
# Porter (2019)
# Porter - American
# 3.957
# Founders Brewing Co.
# https://untappd.com/b/founders-brewing-co-porter-2019/3060481
#
#
# Underground Mountain Brown (2019)
# Brown Ale - Imperial / Double
# 4.061
# Founders Brewing Co.
# https://untappd.com/b/founders-brewing-co-underground-mountain-brown-2019/3345035
#
#
# Dandy Rover
# IPA - Imperial / Double
# 3.95
# GAS Brew
# https://untappd.com/b/gas-brew-dandy-rover/3403044
#
#
# Кекс Coconut Edition
# Stout - Pastry
# 3.985
# GAS Brew
# https://untappd.com/b/gas-brew-keks-coconut-edition/3403050
#
#
# RIS -4
# Stout - Russian Imperial
# 3.826
# Green Basement Brewery
# https://untappd.com/b/green-basement-brewery-ris-4/3572535
#
#
# Flying Dutchman (Летучий Голландец) Release 2020
# Stout - Oatmeal
# 3.988
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-flying-dutchman-letuchij-gollandec-release-2020/3680025
#
#
# Грибник (Mushroom Soup)
# Sour - Gose
# 3.59
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-gribnik-mushroom-soup/3628412
#
#
# Солянка (Smoked Bacon Soup)
# Sour - Gose
# 4.185
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-solyanka-smoked-bacon-soup/3406271
#
#
# Томатный Суп с Каролина Рипер (Carolina Reaper Tomato Soup)
# Sour - Gose
# 3.986
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-tomatnyj-sup-s-karolina-riper-carolina-reaper-tomato-soup/3647975
#
#
# Delirium Black Barrel Aged
# Belgian Strong Dark Ale
# 4.048
# Huyghe Brewery
# https://untappd.com/b/huyghe-brewery-delirium-black-barrel-aged/2862156
#
#
# Mlk Matter
# Stout - Milk / Sweet
# 3.72
# Jaws Brewery
# https://untappd.com/b/jaws-brewery-mlk-matter/3795042
#
#
# Human Nature
# Sour - Fruited Gose
# 3.56
# LERVIG
# https://untappd.com/b/lervig-human-nature/3585122
#
#
# It's Not Me, It's You
# Gluten-Free
# 3.931
# LERVIG
# https://untappd.com/b/lervig-it-s-not-me-it-s-you/3550938
#
#
# Naughty & Nice
# Bock - Doppelbock
# 3.622
# LERVIG
# https://untappd.com/b/lervig-naughty-and-nice/3496214
#
#
# Rubinstep Apple Cider
# Cider - Dry
# 3.454
# LERVIG
# https://untappd.com/b/lervig-rubinstep-apple-cider/3632244
#
#
# Battlefield
# Stout - Imperial / Double White
# 3.755
# La Débauche
# https://untappd.com/b/la-debauche-battlefield/2764561
#
#
# Slap a Banker
# Barleywine - American
# 3.742
# La Débauche
# https://untappd.com/b/la-debauche-slap-a-banker/1310590
#
#
# Grand Cru
# Wheat Beer - Witbier
# 3.412
# LaBEERint Brewery
# https://untappd.com/b/labeerint-brewery-grand-cru/2120448
#
#
# Imperial Cider Rioja Barrel Aged (20%)
# Cider - Traditional
# 4.189
# LaBEERint Brewery
# https://untappd.com/b/labeerint-brewery-imperial-cider-rioja-barrel-aged-20/3757326
#
#
# Labeerint of the Minotaur #3
# Barleywine - American
# 3.735
# LaBEERint Brewery
# https://untappd.com/b/labeerint-brewery-labeerint-of-the-minotaur-3/2895357
#
#
# DAO
# Stout - Russian Imperial
# 3.667
# Landau Beerlab
# https://untappd.com/b/landau-beerlab-dao/2530840
#
#
# BBQ Tomato Gose
# Sour - Fruited Gose
# 3.595
# LiS Brew
# https://untappd.com/b/lis-brew-bbq-tomato-gose/3695179
#
#
# Milky Chocolate Pastry Stout
# Stout - Pastry
# 3.541
# LiS Brew
# https://untappd.com/b/lis-brew-milky-chocolate-pastry-stout/3748140
#
#
# Stout Pastry Salty Caramel
# Stout - Pastry
# 3.452
# LiS Brew
# https://untappd.com/b/lis-brew-stout-pastry-salty-caramel/3695187
#
#
# Tomato Gose
# Sour - Fruited Gose
# 3.476
# LiS Brew
# https://untappd.com/b/lis-brew-tomato-gose/3618143
#
#
# Black Wooden Leg
# Barleywine - English
# 3.63
# Lighthouse Brew
# https://untappd.com/b/lighthouse-brew-black-wooden-leg/3542724
#
#
# Dark Bishop
# Stout - Milk / Sweet
# 3.803
# Lux In Tenebris
# https://untappd.com/b/lux-in-tenebris-dark-bishop/3552965
#
#
# First Shard
# IPA - American
# 3.598
# Lux In Tenebris
# https://untappd.com/b/lux-in-tenebris-first-shard/3735299
#
#
# Marzyparty
# Stout - Imperial / Double Milk
# 3.724
# MONYO Brewing Co.
# https://untappd.com/b/monyo-brewing-co-marzyparty/2639859
#
#
# Old Cool
# IPA - American
# 3.804
# Main Rule
# https://untappd.com/b/main-rule-old-cool/3765314
#
#
# Beer Geek Breakfast
# Stout - Oatmeal
# 3.888
# Mikkeller
# https://untappd.com/b/mikkeller-beer-geek-breakfast/179
#
#
# Beer Geek Dessert
# Stout - Imperial / Double Pastry
# 4.079
# Mikkeller
# https://untappd.com/b/mikkeller-beer-geek-dessert/39215
#
#
# Beer Geek Vanilla Maple Cocoa Shake
# Stout - Imperial / Double Oatmeal
# 4.146
# Mikkeller
# https://untappd.com/b/mikkeller-beer-geek-vanilla-maple-cocoa-shake/2390497
#
#
# Beer Geek Vanilla Shake
# Stout - Imperial / Double Oatmeal
# 4.185
# Mikkeller
# https://untappd.com/b/mikkeller-beer-geek-vanilla-shake/371716
#
#
# SpontanCherry Frederiksdal (2019)
# Lambic - Kriek
# 4.163
# Mikkeller
# https://untappd.com/b/mikkeller-spontancherry-frederiksdal-2019/3067311
#
#
# LAYQA
# Stout - Pastry
# 3.828
# New Riga's Brewery
# https://untappd.com/b/new-riga-s-brewery-layqa/3765978
#
#
# Barium Baltic Porter
# Porter - Baltic
# 3.658
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-barium-baltic-porter/3193740
#
#
# Indium Indian Pale Ale
# IPA - English
# 3.643
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-indium-indian-pale-ale/1816139
#
#
# Kurchatovium
# Pale Ale - New Zealand
# 3.511
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-kurchatovium/2623787
#
#
# Lithium Gose
# Sour - Fruited Gose
# 4.001
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-lithium-gose/3193730
#
#
# Moooolibdenium Pistachio Edition
# IPA - Milkshake
# 3.746
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-moooolibdenium-pistachio-edition/2770426
#
#
# Natrium Gose
# Sour - Gose
# 3.819
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-natrium-gose/3193733
#
#
# Rutherfordium American Pale Ale V 2.0 (с глиттером)
# Pale Ale - New Zealand
# 3.558
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-rutherfordium-american-pale-ale-v-2-0-s-glitterom/2627958
#
#
# Sahti
# Farmhouse Ale - Sahti
# 3.829
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-sahti/2448519
#
#
# Selenium Stout
# Stout - Milk / Sweet
# 3.785
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-selenium-stout/3007895
#
#
# Stibium Sour Black Stout
# Sour - Other
# 3.646
# Nuclear Brewery
# https://untappd.com/b/nuclear-brewery-stibium-sour-black-stout/3462162
#
#
# All Sails Ripped
# Stout - Imperial / Double
# 4.237
# Nøgne Ø
# https://untappd.com/b/nogne-o-all-sails-ripped/3625728
#
#
# Close To the Edge
# Stout - Other
# 3.64
# Nøgne Ø
# https://untappd.com/b/nogne-o-close-to-the-edge/3625693
#
#
# Driftwood²
# Sour - Flanders Oud Bruin
# 3.849
# Nøgne Ø
# https://untappd.com/b/nogne-o-driftwood2/3625726
#
#
# Choco Mammuth
# Stout - Imperial / Double Milk
# 4.085
# One Ton Brewery (Пивоварня Одна Тонна)
# https://untappd.com/b/one-ton-brewery-pivovarnya-odna-tonna-choco-mammuth/1591952
#
#
# Choco Mammuth: Coconut Ed.
# Stout - Imperial / Double Milk
# 4.036
# One Ton Brewery (Пивоварня Одна Тонна)
# https://untappd.com/b/one-ton-brewery-pivovarnya-odna-tonna-choco-mammuth-coconut-ed/3463930
#
#
# Рыжая Соня (Rizhaya Sonya)
# IPA - American
# 3.75
# One Ton Brewery (Пивоварня Одна Тонна)
# https://untappd.com/b/one-ton-brewery-pivovarnya-odna-tonna-ryzhaya-sonya-rizhaya-sonya/1318227
#
#
# Hot Buttered Rum Ten FIDY Barrel-Aged Imperial Stout
# Stout - Imperial / Double Pastry
# 4.069
# Oskar Blues Brewery
# https://untappd.com/b/oskar-blues-brewery-hot-buttered-rum-ten-fidy-barrel-aged-imperial-stout/2995289
#
#
# Honey Gems
# Mead - Melomel
# 4.039
# Ostrovica
# https://untappd.com/b/ostrovica-honey-gems/3723799
#
#
# MAD PRINTER
# IPA - Imperial / Double
# 3.923
# Ostrovica
# https://untappd.com/b/ostrovica-mad-printer/3808840
#
#
# Minor 6th
# IPA - Imperial / Double
# 3.997
# Ostrovica
# https://untappd.com/b/ostrovica-minor-6th/3809672
#
#
# Simpa
# Pale Ale - American
# 3.882
# Ostrovica
# https://untappd.com/b/ostrovica-simpa/3216768
#
#
# Sour Cruise: Lacto Peach
# Sour - Fruited Berliner Weisse
# 3.95
# Ostrovica
# https://untappd.com/b/ostrovica-sour-cruise-lacto-peach/2701208
#
#
# The Fine Line
# Barleywine - English
# 4.004
# Paradox
# https://untappd.com/b/paradox-the-fine-line/3682216
#
#
# Vie Nouvelle
# Sour - Fruited Berliner Weisse
# 3.874
# Pike Season Brewery
# https://untappd.com/b/pike-season-brewery-vie-nouvelle/3792454
#
#
# Come On Baby Light My Fire (Ancho/Pasilla) Whisky BA
# Stout - Russian Imperial
# 4.179
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-come-on-baby-light-my-fire-ancho-pasilla-whisky-ba/3661267
#
#
# Disintegrator
# Porter - Imperial / Double Baltic
# 3.942
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-disintegrator/3091562
#
#
# Satan Infernalis. Second Coming. BBA Version
# Stout - Russian Imperial
# 4.13
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-satan-infernalis-second-coming-bba-version/3626375
#
#
# T And U (New Guinea Version)
# Stout - Russian Imperial
# 4.014
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-t-and-u-new-guinea-version/3528808
#
#
# The Lord of Bounty
# Stout - Imperial / Double Milk
# 4.015
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-the-lord-of-bounty/2616957
#
#
# Tiamat
# Stout - Russian Imperial
# 3.736
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-tiamat/3656630
#
#
# Winterhook (2017)
# Dark Ale
# 3.445
# Redhook Brewery
# https://untappd.com/b/redhook-brewery-winterhook-2017/2375386
#
#
# Vote
# Stout - Russian Imperial
# 3.893
# Rewort Brewery
# https://untappd.com/b/rewort-brewery-vote/3745524
#
#
# Энергия
# Winter Warmer
# 3.468
# Rocket City Brewery
# https://untappd.com/b/rocket-city-brewery-energiya/3587175
#
#
# Chocolate Stout
# Stout - American
# 3.814
# Rogue Ales
# https://untappd.com/b/rogue-ales-chocolate-stout/4178
#
#
# Hazelnut Brown Nectar
# Brown Ale - American
# 3.804
# Rogue Ales
# https://untappd.com/b/rogue-ales-hazelnut-brown-nectar/4179
#
#
# Соло
# IPA - American
# 3.876
# Samovar Brew
# https://untappd.com/b/samovar-brew-solo/3671217
#
#
# August
# Sour - Other
# 3.817
# Schneeeule
# https://untappd.com/b/schneeeule-august/3262655
#
#
# Flora
# Sour - Other
# 4.078
# Schneeeule
# https://untappd.com/b/schneeeule-flora/3302384
#
#
# Лещ (Bream)
# Stout - Milk / Sweet
# 4.167
# Sergacore Brewery
# https://untappd.com/b/sergacore-brewery-lesh-bream/2257350
#
#
# Dark Humor Club - Bourbon Vanilla
# Stout - Imperial / Double
# 3.844
# Sori Brewing
# https://untappd.com/b/sori-brewing-dark-humor-club-bourbon-vanilla/1194403
#
#
# Dark Humor Club - Coconut
# Stout - Imperial / Double
# 3.74
# Sori Brewing
# https://untappd.com/b/sori-brewing-dark-humor-club-coconut/1194407
#
#
# Laudatur (XIX) 2019
# Strong Ale - American
# 3.909
# Sori Brewing
# https://untappd.com/b/sori-brewing-laudatur-xix-2019/3145915
#
#
# Polyphemus
# Stout - Imperial / Double
# 3.779
# Sori Brewing
# https://untappd.com/b/sori-brewing-polyphemus/3102354
#
#
# Hoppymilk Milkshake Mango
# Pale Ale - Milkshake
# 3.979
# Stamm Brewing
# https://untappd.com/b/stamm-beer-hoppymilk-milkshake-mango/2248649
#
#
# Juice & Juice Blood Orange
# IPA - Milkshake
# 4.063
# Stamm Brewing
# https://untappd.com/b/stamm-brewing-juice-and-juice-blood-orange/2550794
#
#
# Juice & Juice Mandarina Jugosa
# IPA - New England
# 4.033
# Stamm Brewing
# https://untappd.com/b/stamm-beer-juice-and-juice-mandarina-jugosa/2617735
#
#
# Symbiotica Apple
# Cider - Traditional
# 3.731
# Symbiotica by AF Brew × BSG
# https://untappd.com/b/symbiotica-by-af-brew-bsg-symbiotica-apple/3707608
#
#
# Sweet Touch Grapefruit
# Fruit Beer
# 3.19
# Taiwan Tobacco & Liquor Corporation
# https://untappd.com/b/taiwan-tobacco-and-liquor-corporation-sweet-touch-grapefruit/2047539
#
#
# Sweet Touch Lychee
# Fruit Beer
# 3.128
# Taiwan Tobacco & Liquor Corporation
# https://untappd.com/b/taiwan-tobacco-and-liquor-corporation-sweet-touch-lychee/254452
#
#
# Sweet Touch White Grape
# Fruit Beer
# 2.757
# Taiwan Tobacco & Liquor Corporation
# https://untappd.com/b/taiwan-tobacco-and-liquor-corporation-sweet-touch-white-grape/254470
#
#
# Frucht: Fruit Punch
# Sour - Fruited Berliner Weisse
# 3.93
# The Bruery Terreux
# https://untappd.com/b/the-bruery-terreux-frucht-fruit-punch/2872690
#
#
# Frucht: Grapefruit & Salt
# Sour - Fruited Berliner Weisse
# 3.899
# The Bruery Terreux
# https://untappd.com/b/the-bruery-terreux-frucht-grapefruit-and-salt/3062241
#
#
# Black Boar - Barrel Aged Batch III 2017
# Stout - Imperial / Double Oatmeal
# 3.956
# The White Hag Irish Brewing Company
# https://untappd.com/b/the-white-hag-irish-brewing-company-black-boar-barrel-aged-batch-iii-2017/3016501
#
#
# The Blend 2018
# Wild Ale - Other
# 3.95
# The Wild Beer Co
# https://untappd.com/b/the-wild-beer-co-the-blend-2018/2737972
#
#
#  Quadrupel
# Belgian Quadrupel
# 3.659
# Trigger
# https://untappd.com/b/trigger-quadrupel/1083003
#
#
# Dark Reality
# Stout - Russian Imperial
# 4.147
# Velka Morava
# https://untappd.com/b/velka-morava-dark-reality/3701872
#
#
# Имя Розы
# Belgian Tripel
# 3.79
# Velka Morava
# https://untappd.com/b/velka-morava-imya-rozy/3727039
#
#
# Aztecs Pleasures
# Chilli / Chile Beer
# 3.747
# Victory Art Brew
# https://untappd.com/b/victory-art-brew-aztecs-pleasures/3263611
#
#
# Queen Mary Old Burton Ale 2017 Brett Edition
# Burton Ale
# 3.737
# Victory Art Brew
# https://untappd.com/b/victory-art-brew-queen-mary-old-burton-ale-2017-brett-edition/2597138
#
#
# Abensberger Dunkel
# Lager - Munich Dunkel
# 3.464
# Weissbierbrauer Kuchlbauer
# https://untappd.com/b/weissbierbrauer-kuchlbauer-abensberger-dunkel/429714
#
#
# G.O.S.E | Cherry & Tonka
# Sour - Fruited Gose
# 3.81
# XP Brew
# https://untappd.com/b/xp-brew-g-o-s-e-cherry-and-tonka/3817788
#
#
# G.O.S.E. | Raspberry & Ginger
# Sour - Fruited Gose
# 3.755
# XP Brew
# https://untappd.com/b/xp-brew-g-o-s-e-raspberry-and-ginger/3817466
#
#
# G.see Boost
# IPA - Imperial / Double New England
# 4.001
# XP Brew
# https://untappd.com/b/xp-brew-g-see-boost/3713972
#
#
# All Summer In A Day
# Sour - Fruited Gose
# 4.002
# Zagovor Brewery
# https://untappd.com/b/zagovor-brewery-all-summer-in-a-day/2353314
#
#
# Cloudy Moscow IPA
# IPA - New England
# 3.955
# Zagovor Brewery
# https://untappd.com/b/zagovor-brewery-cloudy-moscow-ipa/2051823
#
#
# Moon Sign
# Sour - Fruited
# 4.061
# Zagovor Brewery
# https://untappd.com/b/zagovor-brewery-moon-sign/3668114
#
#
# The Charming Man
# Sour - Fruited
# 4.059
# Zagovor Brewery
# https://untappd.com/b/zagovor-brewery-the-charming-man/2650807
#
#
# Trafaret
# Sour - Fruited Gose
# 3.963
# Zagovor Brewery
# https://untappd.com/b/zagovor-brewery-trafaret/2471178
#
#
# Gypsy Boy & Apple Monster
# Cider - Dry
# 3.734
# Заповедник
# https://untappd.com/b/zapovednik-gypsy-boy-and-apple-monster/3205086
#
#
# АБАНАМАТ
# Cider - Dry
# 3.991
# Заповедник
# https://untappd.com/b/zapovednik-abanamat/1963594
#
#
# Сон Масала / Dream Masala
# Mead - Braggot
# 4.064
# Пивоварня Чаща / Thicket Brewery
# https://untappd.com/b/pivovarnya-chasha-thicket-brewery-son-masala-dream-masala/3378680
#
#
# Крымский IPA
# IPA - International
# 3.105
# Пивоварня Якорь
# https://untappd.com/b/pivovarnya-yakor-krymskij-ipa/2713186
#
#
# Эликсир Друидов
# Farmhouse Ale - Saison
# 3.408
# Рузская Пивоваренная Компания
# https://untappd.com/b/ruzskaya-pivovarennaya-kompaniya-eliksir-druidov/2020403
#
#
# Patricide
# Mead - Metheglin
# 3.953
# Та-Та
# https://untappd.com/b/ta-ta-patricide/3682224

# %%
bdp.parse_the_list('brewery.html', 'brewery')
# Out:
# haha
# Redrum IPA Special Edition
# IPA - Imperial / Double
# 3.96
# similar
# https://untappd.com/b/af-brew-redrum-ipa-special-edition/915280
#
#
# Mosaic IPA
# IPA - American
# 3.96
# similar
# https://untappd.com/b/af-brew-mosaic-ipa/309806
#
#
# Big Black Mash
# Stout - Imperial / Double Pastry
# 3.96
# similar
# https://untappd.com/b/af-brew-big-black-mash/2588712
#
#
# Eat the Dust! DDH Mosaic
# IPA - Imperial / Double New England
# 4.16
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-mosaic/2065074
#
#
# Ingria Pale Ale
# IPA - American
# 4.08
# similar
# https://untappd.com/b/af-brew-ingria-pale-ale/222101
#
#
# Passion Is My Confession
# Sour - Fruited Berliner Weisse
# 3.87
# similar
# https://untappd.com/b/af-brew-passion-is-my-confession/1722897
#
#
# Зимняя Меланхолия (Winter Melancholy)
# Porter - Imperial / Double Baltic
# 3.98
# similar
# https://untappd.com/b/af-brew-zimnyaya-melanholiya-winter-melancholy/1361616
#
#
# Eat the Dust! DDH Citra
# IPA - Imperial / Double New England
# 4.07
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-citra/2180082
#
#
# Raspberry Is My Sanctuary
# Sour - Fruited Berliner Weisse
# 4.06
# similar
# https://untappd.com/b/af-brew-raspberry-is-my-sanctuary/2042006
#
#
# Quad Hopper
# IPA - Quadruple
# 3.9
# similar
# https://untappd.com/b/af-brew-quad-hopper/2701284
#
#
# Old Sparky
# IPA - Triple
# 4.13
# similar
# https://untappd.com/b/af-brew-old-sparky/1345728
#
#
# Oodles of Labradoodles
# IPA - New England
# 3.97
# similar
# https://untappd.com/b/af-brew-oodles-of-labradoodles/2366528
#
#
# Hoppy Surf
# Pale Ale - American
# 4
# similar
# https://untappd.com/b/af-brew-hoppy-surf/418241
#
#
# Breeder Reactor
# IPA - New England
# 3.78
# similar
# https://untappd.com/b/af-brew-breeder-reactor/2484830
#
#
# Hentai
# IPA - American
# 3.91
# similar
# https://untappd.com/b/af-brew-hentai/678907
#
#
# Black Magic
# Porter - American
# 3.73
# similar
# https://untappd.com/b/af-brew-black-magic/463804
#
#
# Candyman! Candyman! Candyman! Candyman! Candyman!
# Stout - Imperial / Double Pastry
# 3.73
# similar
# https://untappd.com/b/af-brew-candyman-candyman-candyman-candyman-candyman/2955294
#
#
# Bounty Killer
# Stout - Milk / Sweet
# 4.14
# similar
# https://untappd.com/b/af-brew-bounty-killer/1498332
#
#
# It’s Over 9000! Raspberry • Cherry • Lime
# Sour - Fruited Gose
# 3.81
# similar
# https://untappd.com/b/af-brew-it-s-over-9000-raspberry-cherry-lime/3113439
#
#
# F*ck the Dust! DDH Citra
# IPA - Triple New England
# 4.02
# similar
# https://untappd.com/b/af-brew-f-ck-the-dust-ddh-citra/3217815
#
#
# Serotonin Syndrome
# Stout - Imperial / Double Oatmeal
# 4.14
# similar
# https://untappd.com/b/af-brew-serotonin-syndrome/2038885
#
#
# Popcorn Pimp
# Stout - Imperial / Double Pastry
# 4.05
# similar
# https://untappd.com/b/af-brew-popcorn-pimp/2879438
#
#
# Redneck Ale
# Pumpkin / Yam Beer
# 4.12
# similar
# https://untappd.com/b/af-brew-redneck-ale/257189
#
#
# It’s Over 9000! Mango • Pineapple • Lime
# Sour - Fruited Gose
# 3.71
# similar
# https://untappd.com/b/af-brew-it-s-over-9000-mango-pineapple-lime/3301683
#
#
# Fat Nelson
# IPA - Triple New England
# 3.92
# similar
# https://untappd.com/b/af-brew-fat-nelson/2943649
#
#
# It’s Over 9000! Passion Fruit • Peach • Lime
# Sour - Fruited Gose
# 3.97
# similar
# https://untappd.com/b/af-brew-it-s-over-9000-passion-fruit-peach-lime/3168503
#
#
# Kiss the Dust! DDH Mosaic+Citra
# IPA - Sour
# 4.04
# similar
# https://untappd.com/b/af-brew-kiss-the-dust-ddh-mosaic-citra/3133446
#
#
# ABV Not IBU: Amarillo
# IPA - Imperial / Double
# 4.06
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-amarillo/885555
#
#
# I Got Guava Worms
# IPA - Sour
# 3.93
# similar
# https://untappd.com/b/af-brew-i-got-guava-worms/3436793
#
#
# Goseline Pump: Blueberry
# Sour - Fruited Gose
# 4.16
# similar
# https://untappd.com/b/af-brew-goseline-pump-blueberry/1592076
#
#
# F*ck the Dust! DDH Mosaic
# IPA - Triple New England
# 3.82
# similar
# https://untappd.com/b/af-brew-f-ck-the-dust-ddh-mosaic/3250642
#
#
# Eat the Dust! DDH Simcoe
# IPA - Imperial / Double New England
# 4.15
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-simcoe/2790770
#
#
# Crossover Milk
# Pale Ale - Milkshake
# 4.01
# similar
# https://untappd.com/b/af-brew-crossover-milk/2410515
#
#
# Dark Side of the Overhype
# Stout - Imperial / Double Pastry
# 3.96
# similar
# https://untappd.com/b/af-brew-dark-side-of-the-overhype/3552894
#
#
# Goseline Pump: Sea Buckthorn
# Sour - Fruited Gose
# 4.13
# similar
# https://untappd.com/b/af-brew-goseline-pump-sea-buckthorn/1624042
#
#
# Лоботомия 2018 Фронтальная (Lobotomy 2018 Frontal) Triple-Bourbon BA
# Stout - Imperial / Double
# 3.99
# similar
# https://untappd.com/b/af-brew-lobotomiya-2018-frontalnaya-lobotomy-2018-frontal-triple-bourbon-ba/2618937
#
#
# Fear of Zefir
# Stout - Imperial / Double Pastry
# 4.39
# similar
# https://untappd.com/b/af-brew-fear-of-zefir/3362305
#
#
# My Wheatberry Nights
# Wheat Beer - American Pale Wheat
# 4.04
# similar
# https://untappd.com/b/af-brew-my-wheatberry-nights/1094107
#
#
# Hip Hop Milk
# Pale Ale - Milkshake
# 3.76
# similar
# https://untappd.com/b/af-brew-hip-hop-milk/1663296
#
#
# Highs And Lows
# IPA - American
# 4.02
# similar
# https://untappd.com/b/af-brew-highs-and-lows/3027684
#
#
# Sour Diesel Therapy: Pineapple ∙ Mango ∙ Passion Fruit
# Sour - Fruited
# 3.81
# similar
# https://untappd.com/b/af-brew-sour-diesel-therapy-pineapple-mango-passion-fruit/3454737
#
#
# Grape Peel Session
# IPA - Session / India Session Ale
# 4.1
# similar
# https://untappd.com/b/af-brew-grape-peel-session/1321980
#
#
# Eat the Dust! DDH Amarillo
# IPA - Imperial / Double New England
# 3.85
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-amarillo/2872614
#
#
# Sweat, Tears And Swamp Dew
# Sour - Fruited Gose
# 3.98
# similar
# https://untappd.com/b/af-brew-sweat-tears-and-swamp-dew/2366537
#
#
# Lobotomy³ (2019)
# Stout - Imperial / Double
# 4.01
# similar
# https://untappd.com/b/af-brew-lobotomy3-2019/3305840
#
#
# It’s Over 9000! Blackberry • Strawberry • Lime
# Sour - Fruited Gose
# 4.3
# similar
# https://untappd.com/b/af-brew-it-s-over-9000-blackberry-strawberry-lime/3306258
#
#
# Kiss the Dust! DDH Citra+Simcoe
# IPA - Sour
# 3.9
# similar
# https://untappd.com/b/af-brew-kiss-the-dust-ddh-citra-simcoe/3250632
#
#
# I Got Mango Worms
# IPA - Sour
# 3.98
# similar
# https://untappd.com/b/af-brew-i-got-mango-worms/3500423
#
#
# Bus 22
# Pilsner - Czech
# 4.03
# similar
# https://untappd.com/b/af-brew-bus-22/2620029
#
#
# Golden Balls
# IPA - Imperial / Double New England
# 3.68
# similar
# https://untappd.com/b/af-brew-golden-balls/3148067
#
#
# Эйфория (Euphoria)
# IPA - American
# 3.97
# similar
# https://untappd.com/b/af-brew-ejforiya-euphoria/1057968
#
#
# Goseline Pump: Gooseberry
# Sour - Fruited Gose
# 3.98
# similar
# https://untappd.com/b/af-brew-goseline-pump-gooseberry/2193004
#
#
# Greenhouse Fresh
# Sour - Fruited Gose
# 3.83
# similar
# https://untappd.com/b/af-brew-greenhouse-fresh/3313855
#
#
# Black Mass Is My Cassis
# Sour - Fruited Berliner Weisse
# 3.78
# similar
# https://untappd.com/b/af-brew-black-mass-is-my-cassis/2271318
#
#
# Sangre Fresca
# Sour - Fruited Gose
# 3.86
# similar
# https://untappd.com/b/af-brew-sangre-fresca/3607569
#
#
# Multimicrodots
# IPA - New England
# 3.62
# similar
# https://untappd.com/b/af-brew-multimicrodots/3286160
#
#
# Piña Collabo
# Sour - Fruited
# 3.81
# similar
# https://untappd.com/b/af-brew-pina-collabo/3348503
#
#
# Love And Squalor
# Barleywine - American
# 3.97
# similar
# https://untappd.com/b/af-brew-love-and-squalor/2605644
#
#
# ALL • GRAIN • CORE
# Stout - Other
# 4.11
# similar
# https://untappd.com/b/af-brew-all-grain-core/3557493
#
#
# All Together
# IPA - New England
# 3.73
# similar
# https://untappd.com/b/af-brew-all-together/3759886
#
#
# The Seven Year Itch
# IPA - Imperial / Double New England
# 4.04
# similar
# https://untappd.com/b/af-brew-the-seven-year-itch/3410263
#
#
# Fortune Cookie Policy
# Sour - Fruited
# 4.03
# similar
# https://untappd.com/b/af-brew-fortune-cookie-policy/3674886
#
#
# Blown Agent Orange
# IPA - Milkshake
# 3.93
# similar
# https://untappd.com/b/af-brew-blown-agent-orange/3133452
#
#
# So Glitchy Lychee!
# IPA - Milkshake
# 3.91
# similar
# https://untappd.com/b/af-brew-so-glitchy-lychee/2768301
#
#
# Malt Factoid
# IPA - New England
# 3.81
# similar
# https://untappd.com/b/af-brew-malt-factoid/3345898
#
#
# I Got Dragon Worms
# IPA - Sour
# 3.85
# similar
# https://untappd.com/b/af-brew-i-got-dragon-worms/3561165
#
#
# Deep Soul Milk
# Pale Ale - Milkshake
# 3.68
# similar
# https://untappd.com/b/af-brew-deep-soul-milk/1846033
#
#
# ABV Not IBU: Motueka
# IPA - Imperial / Double
# 3.93
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-motueka/1853604
#
#
# Out of the Box
# IPA - Imperial / Double New England
# 3.83
# similar
# https://untappd.com/b/af-brew-out-of-the-box/3348500
#
#
# Hoek Van Nieuw Holland
# Wheat Beer - Witbier
# 3.83
# similar
# https://untappd.com/b/af-brew-hoek-van-nieuw-holland/2248906
#
#
# Double Chocolate Banana Cake
# Stout - Imperial / Double Pastry
# 3.72
# similar
# https://untappd.com/b/af-brew-double-chocolate-banana-cake/3516467
#
#
# Hangover Sap
# IPA - New England
# 3.85
# similar
# https://untappd.com/b/af-brew-hangover-sap/3348506
#
#
# Sweat, Tears And Strawberry Fields
# Sour - Fruited Gose
# 3.82
# similar
# https://untappd.com/b/af-brew-sweat-tears-and-strawberry-fields/2544221
#
#
# Annual Farewell Freak Show
# Stout - Imperial / Double Pastry
# 3.99
# similar
# https://untappd.com/b/af-brew-annual-farewell-freak-show/3637188
#
#
# Three Identical Strangers: ADHA 483
# IPA - Imperial / Double New England
# 3.88
# similar
# https://untappd.com/b/af-brew-three-identical-strangers-adha-483/3697721
#
#
# Kupola & Pastila
# Stout - Imperial / Double Pastry
# 3.92
# similar
# https://untappd.com/b/af-brew-kupola-and-pastila/2724120
#
#
# Multiacidmicrodots
# IPA - Sour
# 4.07
# similar
# https://untappd.com/b/af-brew-multiacidmicrodots/3373826
#
#
# Do You Know the Muffin Man?
# Stout - Imperial / Double Pastry
# 3.78
# similar
# https://untappd.com/b/af-brew-do-you-know-the-muffin-man/2993853
#
#
# Sour Diesel Therapy: Raspberry ∙ Blueberry ∙ Blackberry
# Sour - Fruited
# 4.1
# similar
# https://untappd.com/b/af-brew-sour-diesel-therapy-raspberry-blueberry-blackberry/3683577
#
#
# Do You Know the Blueberry Man?
# Stout - Imperial / Double Pastry
# 3.81
# similar
# https://untappd.com/b/af-brew-do-you-know-the-blueberry-man/3203144
#
#
# Blown Agent Purple
# IPA - Milkshake
# 4.15
# similar
# https://untappd.com/b/af-brew-blown-agent-purple/3110024
#
#
# Lemon Haze
# Pale Ale - American
# 3.67
# similar
# https://untappd.com/b/af-brew-lemon-haze/2149415
#
#
# Bold In Gold
# IPA - Triple New England
# 3.82
# similar
# https://untappd.com/b/af-brew-bold-in-gold/3731157
#
#
# Stereo Vario: Calamansi And Mint
# Sour - Fruited Berliner Weisse
# 3.84
# similar
# https://untappd.com/b/af-brew-stereo-vario-calamansi-and-mint/2752952
#
#
# Ol' Filthy Popcorn Pimp
# Stout - Imperial / Double Pastry
# 3.82
# similar
# https://untappd.com/b/af-brew-ol-filthy-popcorn-pimp/3194575
#
#
# Supercandyman!
# Stout - Imperial / Double Pastry
# 4.2
# similar
# https://untappd.com/b/af-brew-supercandyman/3227526
#
#
# Big Black Maple Mash
# Stout - Imperial / Double Pastry
# 4.22
# similar
# https://untappd.com/b/af-brew-big-black-maple-mash/2833611
#
#
# Star 14
# IPA - Imperial / Double New England
# 4.09
# similar
# https://untappd.com/b/af-brew-star-14/1914946
#
#
# Three Identical Strangers: HBC 472
# IPA - Imperial / Double New England
# 4.03
# similar
# https://untappd.com/b/af-brew-three-identical-strangers-hbc-472/3724367
#
#
# Меланхолия (Melancholy)
# Porter - Imperial / Double Baltic
# 3.82
# similar
# https://untappd.com/b/af-brew-melanholiya-melancholy/1034462
#
#
# Three Identical Strangers: HBC 438
# IPA - Imperial / Double New England
# 4.08
# similar
# https://untappd.com/b/af-brew-three-identical-strangers-hbc-438/3724365
#
#
# Goseline Pump: Rhubarb
# Sour - Fruited Gose
# 3.85
# similar
# https://untappd.com/b/af-brew-goseline-pump-rhubarb/1665976
#
#
# Sourrealism Citra+Equinox
# Sour - Other
# 3.84
# similar
# https://untappd.com/b/af-brew-sourrealism-citra-equinox/1315567
#
#
# Goseline Pump: Apricot
# Sour - Fruited Gose
# 3.93
# similar
# https://untappd.com/b/af-brew-goseline-pump-apricot/2708473
#
#
# Pomme De Sodome
# Cider - Graff
# 3.87
# similar
# https://untappd.com/b/af-brew-pomme-de-sodome/3588530
#
#
# Peach Is My Preach
# Sour - Fruited Berliner Weisse
# 4.13
# similar
# https://untappd.com/b/af-brew-peach-is-my-preach/2522338
#
#
# Má Là Equinox
# Spiced / Herbed Beer
# 3.71
# similar
# https://untappd.com/b/af-brew-ma-la-equinox/1943466
#
#
# Манго Освобожденный (Mango Unchained)
# Farmhouse Ale - Saison
# 3.81
# similar
# https://untappd.com/b/af-brew-mango-osvobozhdennyj-mango-unchained/1183288
#
#
# Sourrealism Sorachi+Mosaic
# Sour - Other
# 3.67
# similar
# https://untappd.com/b/af-brew-sourrealism-sorachi-mosaic/1396778
#
#
# Goseline Pump: Raspberry
# Sour - Fruited Gose
# 3.99
# similar
# https://untappd.com/b/af-brew-goseline-pump-raspberry/1582550
#
#
# Spanglish Breakfast
# Porter - Imperial / Double
# 4.02
# similar
# https://untappd.com/b/af-brew-spanglish-breakfast/3168592
#
#
# Elementary Operations
# IPA - Imperial / Double New England
# 3.76
# similar
# https://untappd.com/b/af-brew-elementary-operations/2801720
#
#
# Spoonful of Summer
# Pale Ale - New England
# 4.03
# similar
# https://untappd.com/b/af-brew-spoonful-of-summer/2754001
#
#
# Babauhaus
# Sour - Fruited
# 3.92
# similar
# https://untappd.com/b/af-brew-babauhaus/3683487
#
#
# Kiss the Dust! DDH Simcoe+Amarillo
# IPA - Sour
# 3.83
# similar
# https://untappd.com/b/af-brew-kiss-the-dust-ddh-simcoe-amarillo/3275016
#
#
# Bomb Release Unit
# IPA - Imperial / Double New England
# 3.95
# similar
# https://untappd.com/b/af-brew-bomb-release-unit/2558569
#
#
# Stereo Vario: Raspberry And Coffee
# Sour - Fruited Berliner Weisse
# 4.06
# similar
# https://untappd.com/b/af-brew-stereo-vario-raspberry-and-coffee/2752950
#
#
# Carousel Pie
# Pale Ale - New England
# 3.78
# similar
# https://untappd.com/b/af-brew-carousel-pie/2681079
#
#
# Overnight Oatmeal
# IPA - Imperial / Double New England
# 3.82
# similar
# https://untappd.com/b/af-brew-overnight-oatmeal/2993848
#
#
# So Bloody Pink!
# IPA - New England
# 3.8
# similar
# https://untappd.com/b/af-brew-so-bloody-pink/2608945
#
#
# Nero Di Seppia
# IPA - Black / Cascadian Dark Ale
# 4.17
# similar
# https://untappd.com/b/af-brew-nero-di-seppia/1673806
#
#
# Serotonin Syndrome ⚡️Convulsive Attack⚡️
# Stout - Imperial / Double Oatmeal
# 3.75
# similar
# https://untappd.com/b/af-brew-serotonin-syndrome-convulsive-attack/2389200
#
#
# Slavic Squat
# Pale Ale - American
# 4.2
# similar
# https://untappd.com/b/af-brew-slavic-squat/2006324
#
#
# Goseline Pump: Watermelon
# Sour - Fruited Gose
# 3.71
# similar
# https://untappd.com/b/af-brew-goseline-pump-watermelon/2778066
#
#
# Eat the Dust! DDH Centennial
# IPA - Imperial / Double New England
# 3.72
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-centennial/2993852
#
#
# Unholy Melancholy
# Porter - Imperial / Double Baltic
# 3.94
# similar
# https://untappd.com/b/af-brew-unholy-melancholy/3649365
#
#
# Sourrealism Galaxy+Vic Secret
# Sour - Other
# 4.12
# similar
# https://untappd.com/b/af-brew-sourrealism-galaxy-vic-secret/1430597
#
#
# Jump the Line
# IPA - Triple
# 3.79
# similar
# https://untappd.com/b/af-brew-jump-the-line/2107375
#
#
# Espressourrealism
# Sour - Other
# 3.99
# similar
# https://untappd.com/b/af-brew-espressourrealism/1983870
#
#
# Neodekadents
# Stout - Imperial / Double
# 3.88
# similar
# https://untappd.com/b/af-brew-neodekadents/2191406
#
#
# Passion RAF
# IPA - New England
# 4.02
# similar
# https://untappd.com/b/af-brew-passion-raf/2135499
#
#
# Tour De Hobo
# IPA - Session / India Session Ale
# 3.87
# similar
# https://untappd.com/b/af-brew-tour-de-hobo/2267070
#
#
# Generation Snowflake
# IPA - Session / India Session Ale
# 3.82
# similar
# https://untappd.com/b/af-brew-generation-snowflake/2452805
#
#
# Neodekadents BA
# Stout - Imperial / Double
# 3.79
# similar
# https://untappd.com/b/af-brew-neodekadents-ba/2585149
#
#
# Eat the Dust! DDH Ekuanot
# IPA - Imperial / Double New England
# 3.91
# similar
# https://untappd.com/b/af-brew-eat-the-dust-ddh-ekuanot/2522340
#
#
# Kochere Espresso
# IPA - Black / Cascadian Dark Ale
# 3.8
# similar
# https://untappd.com/b/af-brew-kochere-espresso/1334279
#
#
# ABV Not IBU: Polaris
# IPA - Imperial / Double
# 4.1
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-polaris/845444
#
#
# Do You Know the Muffin Man Who Went to Bourbon Land?
# Stout - Imperial / Double Pastry
# 4
# similar
# https://untappd.com/b/af-brew-do-you-know-the-muffin-man-who-went-to-bourbon-land/3475246
#
#
# Lemon Pills
# Pilsner - Other
# 4.11
# similar
# https://untappd.com/b/af-brew-lemon-pills/2257271
#
#
# Fruit Sour IPA
# IPA - Sour
# 3.64
# similar
# https://untappd.com/b/af-brew-fruit-sour-ipa/1565160
#
#
# China Equinox
# Belgian Strong Golden Ale
# 4.02
# similar
# https://untappd.com/b/af-brew-china-equinox/1818574
#
#
# Eat No Dust! DDH Nelson Sauvin
# IPA - Imperial / Double New England
# 3.83
# similar
# https://untappd.com/b/af-brew-eat-no-dust-ddh-nelson-sauvin/2255386
#
#
# Another Million Minutes On Cherry
# American Wild Ale
# 3.83
# similar
# https://untappd.com/b/af-brew-another-million-minutes-on-cherry/3718068
#
#
# Шоколадная Антифабрика
# Stout - Imperial / Double Oatmeal
# 4.06
# similar
# https://untappd.com/b/af-brew-shokoladnaya-antifabrika/837557
#
#
# Black Equinox
# Spiced / Herbed Beer
# 4.02
# similar
# https://untappd.com/b/af-brew-black-equinox/1126429
#
#
# Million Minutes of Nothing
# American Wild Ale
# 3.81
# similar
# https://untappd.com/b/af-brew-million-minutes-of-nothing/3084365
#
#
# Tram 16
# Hefeweizen
# 4.01
# similar
# https://untappd.com/b/af-brew-tram-16/3739343
#
#
# Equinox
# Belgian Strong Golden Ale
# 3.76
# similar
# https://untappd.com/b/af-brew-equinox/1005434
#
#
# Another Million Minutes On Raspberry
# American Wild Ale
# 4.05
# similar
# https://untappd.com/b/af-brew-another-million-minutes-on-raspberry/3718062
#
#
# Mash. Boil. Beans. Repeat.
# Stout - Imperial / Double
# 4.02
# similar
# https://untappd.com/b/af-brew-mash-boil-beans-repeat/3793442
#
#
# 8 Weeks And Counting
# IPA - Imperial / Double New England
# 3.73
# similar
# https://untappd.com/b/af-brew-8-weeks-and-counting/3802626
#
#
# Ванильная Икра (Vanilla Caviar)
# Porter - Other
# 4.02
# similar
# https://untappd.com/b/af-brew-vanilnaya-ikra-vanilla-caviar/1868681
#
#
# Flatpicking Day
# IPA - American
# 3.83
# similar
# https://untappd.com/b/af-brew-flatpicking-day/3367186
#
#
# ABV Not IBU: Nelson Sauvin
# IPA - Imperial / Double
# 3.53
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-nelson-sauvin/3793347
#
#
# Grape Peel Session: Sour Side
# Sour - Fruited
# 3.47
# similar
# https://untappd.com/b/af-brew-grape-peel-session-sour-side/1685482
#
#
# Belka+Strelka
# IPA - American
# 3.9
# similar
# https://untappd.com/b/af-brew-belka-strelka/1529937
#
#
# Million Minutes On Raspberry
# American Wild Ale
# 3.73
# similar
# https://untappd.com/b/af-brew-million-minutes-on-raspberry/3084368
#
#
# Baltic Sea Buckthorn Tripel
# Belgian Tripel
# 4.07
# similar
# https://untappd.com/b/af-brew-baltic-sea-buckthorn-tripel/1231315
#
#
# Another Million Minutes On Peach
# American Wild Ale
# 3.93
# similar
# https://untappd.com/b/af-brew-another-million-minutes-on-peach/3718066
#
#
# ABV Not IBU: Citra
# IPA - Imperial / Double
# 3.82
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-citra/3793348
#
#
# Renaissance
# Lager - IPL (India Pale Lager)
# 3.55
# similar
# https://untappd.com/b/af-brew-renaissance/2812848
#
#
# Goseline Pump: Blackberry
# Sour - Fruited Gose
# 3.73
# similar
# https://untappd.com/b/af-brew-goseline-pump-blackberry/1643332
#
#
# Million Minutes On Cloudberry
# American Wild Ale
# 3.89
# similar
# https://untappd.com/b/af-brew-million-minutes-on-cloudberry/3084371
#
#
# ABV Not IBU: Kazbek
# IPA - Imperial / Double
# 3.98
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-kazbek/967628
#
#
# Redrum IPA
# IPA - American
# 3.91
# similar
# https://untappd.com/b/af-brew-redrum-ipa/357754
#
#
# ABV Not IBU: Mandarina Bavaria
# IPA - Imperial / Double
# 4.05
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-mandarina-bavaria/1016152
#
#
# ABV Not IBU: Azacca
# IPA - Imperial / Double
# 3.8
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-azacca/1040478
#
#
# ABV Not IBU: Waimea
# IPA - Imperial / Double
# 3.82
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-waimea/951035
#
#
# ABV Not IBU: Belma
# IPA - Imperial / Double
# 3.85
# similar
# https://untappd.com/b/af-brew-abv-not-ibu-belma/919802
#
#
# Black Kiwi
# Schwarzbier
# 4.08
# similar
# https://untappd.com/b/af-brew-black-kiwi/898538
#
#
# Sudden Breakthru At Checkpoint Charlie
# IPA - Imperial / Double
# 3.97
# similar
# https://untappd.com/b/af-brew-sudden-breakthru-at-checkpoint-charlie/1204170
#
#
# This Is England, Honey!
# Pale Ale - English
# 4.05
# similar
# https://untappd.com/b/af-brew-this-is-england-honey/708885
#
#
# White Kiwi
# Pilsner - Imperial / Double
# 3.74
# similar
# https://untappd.com/b/af-brew-white-kiwi/873356
#
#
# Hoppy Surf: New Zealand Slash
# Pale Ale - New Zealand
# 4.06
# similar
# https://untappd.com/b/af-brew-hoppy-surf-new-zealand-slash/943607
#
#
# Animal Farm
# Farmhouse Ale - Saison
# 3.63
# similar
# https://untappd.com/b/af-brew-animal-farm/728358
#
#
# Tu Vuò Fà L’Americano
# Red Ale - American Amber / Red
# 3.79
# similar
# https://untappd.com/b/af-brew-tu-vuo-fa-l-americano/619326
#
#
# Ninja Bavarese
# Hefeweizen
# 3.88
# similar
# https://untappd.com/b/af-brew-ninja-bavarese/619398
#
#
# Breaking Bad | Первый Saison
# Farmhouse Ale - Saison
# 3.93
# similar
# https://untappd.com/b/af-brew-breaking-bad-pervyj-saison/457370
#
#
# Зимняя Меланхолия (Winter Melancholy) BA Chivas
# Porter - Imperial / Double Baltic
# 4.19
# similar
# https://untappd.com/b/af-brew-zimnyaya-melanholiya-winter-melancholy-ba-chivas/1990751
#
#
# Burton Ale | Citra Edition
# Burton Ale
# 4.08
# similar
# https://untappd.com/b/af-brew-burton-ale-citra-edition/383155
#
#
# Burton Ale | Warrior Edition
# Burton Ale
# 4.22
# similar
# https://untappd.com/b/af-brew-burton-ale-warrior-edition/379612
#
#
# Burton Ale | Willamette Edition
# Burton Ale
# 4
# similar
# https://untappd.com/b/af-brew-burton-ale-willamette-edition/376349
#
#
# Up the Masts!
# Sour - Gose
# 3.93
# similar
# https://untappd.com/b/af-brew-up-the-masts/2798794
#
#
# Заводной Апельсин
# Pale Ale - American
# 3.98
# similar
# https://untappd.com/b/af-brew-zavodnoj-apelsin/460335
#
#
# Burov Stout
# Stout - Other
# 4.24
# similar
# https://untappd.com/b/af-brew-burov-stout/533965
#
#
# Breaking Bad | Director's Cut
# Farmhouse Ale - Saison
# 4.19
# similar
# https://untappd.com/b/af-brew-breaking-bad-director-s-cut/541631
#
#
# Old Sparky BA on Death Row
# Strong Ale - American
# 3.92
# similar
# https://untappd.com/b/af-brew-old-sparky-ba-on-death-row/2269378
#
#
# Redneck Ale Vintage
# Pumpkin / Yam Beer
# 3.97
# similar
# https://untappd.com/b/af-brew-redneck-ale-vintage/339190
#
#
# Tintin Blond
# Belgian Strong Golden Ale
# 3.68
# similar
# https://untappd.com/b/af-brew-tintin-blond/504117

# %%
bdp.parse_the_list('acc.html', 'acc')
# Out:
# haha
# (REMIX) Tiki Jazz
# Sour - Fruited
# 4.0
# Jaws Brewery
# https://untappd.com/b/jaws-brewery-remix-tiki-jazz/3724443
#
#
# Baltika #0 Grapefruit / Балтика #0 Грейпфрут
# Non-Alcoholic Beer
# 4.0
# Baltika Breweries (Балтика)
# https://untappd.com/b/baltika-breweries-baltika-baltika-0-grapefruit-baltika-0-grejpfrut/2908872
#
#
# Symbiotica Apple
# Cider - Traditional
# 4.0
# Symbiotica by AF Brew × BSG
# https://untappd.com/b/symbiotica-by-af-brew-bsg-symbiotica-apple/3707608
#
#
# Pomme De Sodome
# Cider - Graff
# 4.5
# AF Brew
# https://untappd.com/b/af-brew-pomme-de-sodome/3588530
#
#
# All Together
# IPA - New England
# 4.0
# AF Brew
# https://untappd.com/b/af-brew-all-together/3759886
#
#
# Нимфоманка (Nymphomaniac)
# Barleywine - English
# 4.0
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-nimfomanka-nymphomaniac/1712644
#
#
# Bye Bye Take Your Pie
# Stout - Imperial / Double Milk
# 3.5
# Bottle Share
# https://untappd.com/b/bottle-share-bye-bye-take-your-pie/3635282
#
#
# Cherry Merry Princess
# Sour - Other
# 4.0
# HumptyDumpty
# https://untappd.com/b/humptydumpty-cherry-merry-princess/2790686
#
#
# Oak Smoked Tomato Gose
# Spiced / Herbed Beer
# 5.0
# Salden's Brewery
# https://untappd.com/b/salden-s-brewery-oak-smoked-tomato-gose/2028401
#
#
# Quad Hopper
# IPA - Quadruple
# 4.25
# AF Brew
# https://untappd.com/b/af-brew-quad-hopper/2701284
#
#
# Old Sparky
# IPA - Triple
# 4.5
# AF Brew
# https://untappd.com/b/af-brew-old-sparky/1345728
#
#
# Are You Reddy
# Sour - Fruited Berliner Weisse
# 4.0
# Zavod
# https://untappd.com/b/zavod-are-you-reddy/3334036
#
#
# Upgrade DIPA
# IPA - Imperial / Double
# 4.25
# Zavod
# https://untappd.com/b/zavod-upgrade-dipa/3058684
#
#
# 4C AIPA
# IPA - American
# 4.0
# Salden's Brewery
# https://untappd.com/b/salden-s-brewery-4c-aipa/1092950
#
#
# Multimicrodots
# IPA - New England
# 4.0
# AF Brew
# https://untappd.com/b/af-brew-multimicrodots/3286160
#
#
# Young's Double Chocolate Stout
# Stout - Milk / Sweet
# 3.75
# Eagle Brewery (formerly Charles Wells)
# https://untappd.com/b/eagle-brewery-formerly-charles-wells-young-s-double-chocolate-stout/130571
#
#
# Baltika #6 Porter / Балтика #6 Портер
# Porter - Baltic
# 3.5
# Baltika Breweries (Балтика)
# https://untappd.com/b/baltika-breweries-baltika-baltika-6-porter-baltika-6-porter/5149
#
#
# Baltika #4 Original / Балтика #4 Оригинальное
# Lager - Euro Dark
# 3.0
# Baltika Breweries (Балтика)
# https://untappd.com/b/baltika-breweries-baltika-baltika-4-original-baltika-4-originalnoe/19510
#
#
# Zhiguli Barnoe (Жигули Барное)
# Lager - Pale
# 3.5
# Moscow Brewing Company (Московская Пивоваренная Компания)
# https://untappd.com/b/moscow-brewing-company-moskovskaya-pivovarennaya-kompaniya-zhiguli-barnoe-zhiguli-barnoe/26210
#
#
# Затмение (Zatmenie)
# Stout - Imperial / Double Milk
# 4.25
# Bakunin Brewing Co.
# https://untappd.com/b/bakunin-brewing-co-zatmenie-zatmenie/1351738
#
#
# Еловый сидр с мандаринами и гуавой
# Cider - Other Fruit
# 4.5
# Пётр Петрович (Petr Petrovich)
# https://untappd.com/b/pyotr-petrovich-petr-petrovich-elovyj-sidr-s-mandarinami-i-guavoj/3586501
#
#
# 2020
# Barleywine - Other
# 3.0
# ЁD Taproom
# https://untappd.com/b/ed-taproom-2020/3632765
#
#
# Rose Hipped Hibiscus Dipped Flower Power Funky Sour
# Sour - Other
# 4.0
# The Flying Dutchman Nomad Brewing Company
# https://untappd.com/b/the-flying-dutchman-nomad-brewing-company-rose-hipped-hibiscus-dipped-flower-power-funky-sour/1584456
#
#
# Raspberry Pie
# Sour - Fruited
# 3.5
# Landau Beerlab
# https://untappd.com/b/landau-beerlab-raspberry-pie/3205044
#
#
# Hentai
# IPA - American
# 3.0
# AF Brew
# https://untappd.com/b/af-brew-hentai/678907
#
#
# Redrum IPA Special Edition
# IPA - Imperial / Double
# 4.75
# AF Brew
# https://untappd.com/b/af-brew-redrum-ipa-special-edition/915280
#
#
# Vic Secret IPA
# IPA - American
# 3.5
# Nøgne Ø
# https://untappd.com/b/nogne-o-vic-secret-ipa/670187

# %%
bdp.parse_the_list('wishlist.html', 'wishlist')
# Out:
# haha
# Якудза (Yakuza)
# Spiced / Herbed Beer
# 3.56
# Hophead Brewery
# https://untappd.com/b/hophead-brewery-yakudza-yakuza/1309384
#
#
# BANANA BANG
# Sour - Fruited
# 3.81
# FFF BREW
# https://untappd.com/b/fff-brew-banana-bang/3716473
#
#
# SPLURGE
# Sour - Fruited
# 4.46
# Red Button Brewery
# https://untappd.com/b/red-button-brewery-splurge/3690113
#
#
# Tactical Nuclear Penguin
# Freeze-Distilled Beer
# 3.87
# BrewDog
# https://untappd.com/b/brewdog-tactical-nuclear-penguin/5713
#
#
# ARE YOU F**KING NUTS?
# Stout - Russian Imperial
# 4.0
# Browar Minister
# https://untappd.com/b/browar-minister-are-you-f-king-nuts/3167372
#
#
# Duck Diving
# Sour - Fruited Gose
# 3.75
# Brewski
# https://untappd.com/b/brewski-duck-diving/3299131
#
#
# Антропоцентризм / Anthropocentrism
# Stout - Russian Imperial
# 3.75
# Пивоварня Чаща / Thicket Brewery
# https://untappd.com/b/pivovarnya-chasha-thicket-brewery-antropocentrizm-anthropocentrism/3571633
#
#
# The Lord of Bounty
# Stout - Imperial / Double Milk
# 4.02
# Plan B Brewery
# https://untappd.com/b/plan-b-brewery-the-lord-of-bounty/2616957
#
#
# Jamais Vu
# Sour - Other
# 3.95
# FFF BREW
# https://untappd.com/b/fff-brew-jamais-vu/3045120
#
#
# Mr Mint
# Sour - Fruited Gose
# 3.94
# FFF BREW
# https://untappd.com/b/fff-brew-mr-mint/2735143
#
#
# Нефть
# Porter - Imperial / Double
# 3.62
# FFF BREW
# https://untappd.com/b/fff-brew-neft/2610299
#
#
# Stereo Vario: Calamansi And Mint
# Sour - Fruited Berliner Weisse
# 3.82
# AF Brew
# https://untappd.com/b/af-brew-stereo-vario-calamansi-and-mint/2752952
#
#
# Empress Maria
# Sour - Fruited Gose
# 3.96
# Zavod
# https://untappd.com/b/zavod-empress-maria/2627677

# %%
class FiddlingWithBeers:
    
    def __init__(self):
        pass
    
    def top_beers(self, beers, n):
        for beer in beers:
            if beer['rating'] == None:
                beer['rating'] = 0
        beers_sorted = sorted(beers, key=lambda x: x['rating']) 
        return beers_sorted[-n:]
    
    def top_beers_by_style(self, beers, n):
        for beer in beers:
            if beer['rating'] == None:
                beer['rating'] = 0
        styles = []
        for beer in beers:
            if beer['style'] not in styles:
                styles.append(beer['style'])
        styles = sorted(styles)
        print(styles)
        selected_style = input()
        selected_top = []
        for beer in beers:
            if beer['style'] == selected_style:
                selected_top.append(beer)
        beers_sorted = sorted(selected_top, key=lambda x: x['rating'])
        return beers_sorted[-3:]
    
    def recommend_beer(self, acc_beers, bar_beers, n):
        top = self.top_beers(acc_beers, 10)
        top_acc_styles = []
        for t in top:
            if t['style'] not in top_acc_styles:
                top_acc_styles.append(t['style'])
        selected_style = []
        for beer in bar_beers:
            if beer['style'] in top_acc_styles:
                selected_style.append(beer)
        selected_style_sorted = sorted(selected_style, key=lambda x: x['rating']) 
        return selected_style_sorted[-n:]
    
    def check_wishlist(self, acc_beers, bar_beers):
        result = []
        for beer in acc_beers:
            if beer in bar_beers:
                result.append(beer)
        return result

# %% [markdown]
# Тесты

# %%
fwb = FiddlingWithBeers()

# %%
fwb.top_beers(bar, 2)
# Out:
# [{'beer': 'XYAUYÙ BARREL - RISERVA 2014',
#   'style': 'Barleywine - Other',
#   'rating': 4.494,
#   'brewery': 'BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery',
#   'link': 'https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-barrel-riserva-2014/2963304'},
#  {'beer': "XYAUYU' KENTUCKY - RISERVA 2015",
#   'style': 'Barleywine - Other',
#   'rating': 4.542,
#   'brewery': 'BIRRIFICIO AGRICOLO BALADIN - Baladin Indipendente Italian Farm Brewery',
#   'link': 'https://untappd.com/b/birrificio-agricolo-baladin-baladin-indipendente-italian-farm-brewery-xyauyu-kentucky-riserva-2015/2915525'}]

# %%
fwb.top_beers_by_style(bar, 3)
# Out:
# ['American Wild Ale', 'Barleywine - American', 'Barleywine - English', 'Barleywine - Other', 'Belgian Dubbel', 'Belgian Quadrupel', 'Belgian Strong Dark Ale', 'Belgian Strong Golden Ale', 'Belgian Tripel', 'Bière de Champagne / Bière Brut', 'Bock - Doppelbock', 'Bock - Hell / Maibock / Lentebock', 'Bock - Single / Traditional', 'Bock - Weizenbock', 'Brown Ale - American', 'Brown Ale - Imperial / Double', 'Burton Ale', 'Chilli / Chile Beer', 'Cider - Dry', 'Cider - Herbed / Spiced / Hopped', 'Cider - Other Fruit', 'Cider - Traditional', 'Dark Ale', 'English Bitter', 'Farmhouse Ale - Other', 'Farmhouse Ale - Sahti', 'Farmhouse Ale - Saison', 'Fruit Beer', 'Gluten-Free', 'Hefeweizen', 'IPA - American', 'IPA - Belgian', 'IPA - English', 'IPA - Imperial / Double', 'IPA - Imperial / Double New England', 'IPA - International', 'IPA - Milkshake', 'IPA - New England', 'IPA - Session / India Session Ale', 'IPA - Sour', 'IPA - Triple', 'Lager - Helles', 'Lager - Munich Dunkel', 'Lambic - Framboise', 'Lambic - Gueuze', 'Lambic - Kriek', 'Mead - Braggot', 'Mead - Melomel', 'Mead - Metheglin', 'Non-Alcoholic Beer', 'Pale Ale - American', 'Pale Ale - English', 'Pale Ale - Milkshake', 'Pale Ale - New Zealand', 'Porter - American', 'Porter - Baltic', 'Porter - Imperial / Double Baltic', 'Porter - Other', 'Red Ale - Imperial / Double', 'Sour - Flanders Oud Bruin', 'Sour - Fruited', 'Sour - Fruited Berliner Weisse', 'Sour - Fruited Gose', 'Sour - Gose', 'Sour - Other', 'Stout - American', 'Stout - Imperial / Double', 'Stout - Imperial / Double Coffee', 'Stout - Imperial / Double Milk', 'Stout - Imperial / Double Oatmeal', 'Stout - Imperial / Double Pastry', 'Stout - Imperial / Double White', 'Stout - Milk / Sweet', 'Stout - Oatmeal', 'Stout - Other', 'Stout - Pastry', 'Stout - Russian Imperial', 'Strong Ale - American', 'Strong Ale - English', 'Wheat Beer - Witbier', 'Wild Ale - Other', 'Winter Ale', 'Winter Warmer']
# IPA - American
# [{'beer': 'Соло',
#   'style': 'IPA - American',
#   'rating': 3.876,
#   'brewery': 'Samovar Brew',
#   'link': 'https://untappd.com/b/samovar-brew-solo/3671217'},
#  {'beer': 'BUMPY',
#   'style': 'IPA - American',
#   'rating': 3.896,
#   'brewery': 'Red Button Brewery',
#   'link': 'https://untappd.com/b/red-button-brewery-bumpy/3629982'},
#  {'beer': 'Electrocat',
#   'style': 'IPA - American',
#   'rating': 3.926,
#   'brewery': 'Sabotage',
#   'link': 'https://untappd.com/b/sabotage-electrocat/3202918'}]

# %%
fwb.recommend_beer(acc, bar, 3)
# Out:
# [{'beer': 'Choco Mammuth',
#   'style': 'Stout - Imperial / Double Milk',
#   'rating': 4.085,
#   'brewery': 'One Ton Brewery (Пивоварня Одна Тонна)',
#   'link': 'https://untappd.com/b/one-ton-brewery-pivovarnya-odna-tonna-choco-mammuth/1591952'},
#  {'beer': 'Schoolyard',
#   'style': 'IPA - Triple',
#   'rating': 4.091,
#   'brewery': 'Time Bomb Brewery',
#   'link': 'https://untappd.com/b/time-bomb-brewery-schoolyard/3668058'},
#  {'beer': 'Альтер Эго',
#   'style': 'Stout - Imperial / Double Milk',
#   'rating': 4.221,
#   'brewery': 'Big Village Brewery',
#   'link': 'https://untappd.com/b/big-village-brewery-alter-ego/3801547'}]

# %%
fwb.check_wishlist(wishlist, wishlist)[0]
# Out:
# {'beer': 'Якудза (Yakuza)',
#  'style': 'Spiced / Herbed Beer ',
#  'rating': 3.56,
#  'brewery': 'Hophead Brewery',
#  'link': 'https://untappd.com/b/hophead-brewery-yakudza-yakuza/1309384'}
